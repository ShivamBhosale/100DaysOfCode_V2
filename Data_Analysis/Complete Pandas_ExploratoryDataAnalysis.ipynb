# %% [markdown]
# # Complete Pandas ( Exploratory Data Analysis )

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('autoclean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make num-of-doors  \
# 0           0          3                122  alfa-romero          two
# 1           1          3                122  alfa-romero          two
# 2           2          1                122  alfa-romero          two
# 3           3          2                164         audi         four
# 4           4          2                164         audi         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    peak-rpm  city-mpg  highway-mpg    price city-L/100km  Horsepowerbinned  \
# 0    5000.0        21     8.703704  13495.0    11.190476               low
# 1    5000.0        21     8.703704  16500.0    11.190476               low
# 2    5000.0        19     9.038462  16500.0    12.368421            medium
# 3    5500.0        24     7.833333  13950.0     9.791667               low
# 4    5500.0        18    10.681818  17450.0    13.055556               low
#
#   diesel  gas  aspiration-std  aspiration-turbo
# 0      0    1               1                 0
# 1      0    1               1                 0
# 2      0    1               1                 0
# 3      0    1               1                 0
# 4      0    1               1                 0
#
# [5 rows x 31 columns]

# %%
df.drop("Unnamed: 0",axis="columns",inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  peak-rpm  \
# 0          rwd           front        88.6  0.811148  0.886584  ...    5000.0
# 1          rwd           front        88.6  0.811148  0.886584  ...    5000.0
# 2          rwd           front        94.5  0.822681  0.905947  ...    5000.0
# 3          fwd           front        99.8  0.848630  0.915629  ...    5500.0
# 4          4wd           front        99.4  0.848630  0.918396  ...    5500.0
#
#    city-mpg highway-mpg    price  city-L/100km Horsepowerbinned  diesel  gas  \
# 0        21    8.703704  13495.0     11.190476              low       0    1
# 1        21    8.703704  16500.0     11.190476              low       0    1
# 2        19    9.038462  16500.0     12.368421           medium       0    1
# 3        24    7.833333  13950.0      9.791667              low       0    1
# 4        18   10.681818  17450.0     13.055556              low       0    1
#
#    aspiration-std  aspiration-turbo
# 0               1                 0
# 1               1                 0
# 2               1                 0
# 3               1                 0
# 4               1                 0
#
# [5 rows x 30 columns]

# %% [markdown]
# # 2. Analyzing Individual Feature Patterns using Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             int64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg          float64
# price                float64
# city-L/100km         float64
# Horsepowerbinned      object
# diesel                 int64
# gas                    int64
# aspiration-std         int64
# aspiration-turbo       int64
# dtype: object

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.465190   -0.531954 -0.357612
# normalized-losses   0.465190           1.000000   -0.056518  0.019209
# wheel-base         -0.531954          -0.056518    1.000000  0.874587
# length             -0.357612           0.019209    0.874587  1.000000
# width              -0.232919           0.084195    0.795144  0.841118
# height             -0.541038          -0.370706    0.589435  0.491029
# curb-weight        -0.227691           0.097785    0.776386  0.877728
# engine-size        -0.105790           0.110997    0.569329  0.683360
# bore               -0.130083          -0.029266    0.488760  0.606462
# stroke             -0.008689           0.054929    0.160944  0.129522
# compression-ratio  -0.178515          -0.114525    0.249786  0.158414
# horsepower          0.071380           0.203434    0.351985  0.554408
# peak-rpm            0.273679           0.237748   -0.360704 -0.287031
# city-mpg           -0.035823          -0.218749   -0.470414 -0.670909
# highway-mpg        -0.030190           0.178527    0.578128  0.711597
# price              -0.082201           0.133999    0.583168  0.682986
# city-L/100km        0.063165           0.232682    0.474040  0.659165
# diesel             -0.194311          -0.101437    0.308346  0.212679
# gas                 0.194311           0.101437   -0.308346 -0.212679
# aspiration-std      0.059866           0.006823   -0.257611 -0.234539
# aspiration-turbo   -0.059866          -0.006823    0.257611  0.234539
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.232919 -0.541038    -0.227691    -0.105790 -0.130083
# normalized-losses  0.084195 -0.370706     0.097785     0.110997 -0.029266
# wheel-base         0.795144  0.589435     0.776386     0.569329  0.488760
# length             0.841118  0.491029     0.877728     0.683360  0.606462
# width              1.000000  0.279210     0.867032     0.735433  0.559152
# height             0.279210  1.000000     0.295572     0.067149  0.171101
# curb-weight        0.867032  0.295572     1.000000     0.850594  0.648485
# engine-size        0.735433  0.067149     0.850594     1.000000  0.583798
# bore               0.559152  0.171101     0.648485     0.583798  1.000000
# stroke             0.182939 -0.055351     0.168783     0.203094 -0.055909
# compression-ratio  0.181129  0.261214     0.151362     0.028971  0.005201
# horsepower         0.642176 -0.110114     0.750973     0.810705  0.575707
# peak-rpm          -0.219859 -0.320602    -0.266283    -0.244599 -0.254761
# city-mpg          -0.642704 -0.048640    -0.757414    -0.653658 -0.584508
# highway-mpg        0.728044  0.085892     0.836742     0.777077  0.551943
# price              0.728699  0.134388     0.820825     0.861752  0.532300
# city-L/100km       0.682850 -0.002333     0.791911     0.744952  0.555960
# diesel             0.233880  0.284631     0.217275     0.069594  0.054457
# gas               -0.233880 -0.284631    -0.217275    -0.069594 -0.054457
# aspiration-std    -0.300567 -0.087311    -0.324902    -0.108217 -0.212623
# aspiration-turbo   0.300567  0.087311     0.324902     0.108217  0.212623
#
#                      stroke  ...  horsepower  peak-rpm  city-mpg  highway-mpg  \
# symboling         -0.008689  ...    0.071380  0.273679 -0.035823    -0.030190
# normalized-losses  0.054929  ...    0.203434  0.237748 -0.218749     0.178527
# wheel-base         0.160944  ...    0.351985 -0.360704 -0.470414     0.578128
# length             0.129522  ...    0.554408 -0.287031 -0.670909     0.711597
# width              0.182939  ...    0.642176 -0.219859 -0.642704     0.728044
# height            -0.055351  ...   -0.110114 -0.320602 -0.048640     0.085892
# curb-weight        0.168783  ...    0.750973 -0.266283 -0.757414     0.836742
# engine-size        0.203094  ...    0.810705 -0.244599 -0.653658     0.777077
# bore              -0.055909  ...    0.575707 -0.254761 -0.584508     0.551943
# stroke             1.000000  ...    0.088133 -0.066844 -0.042179     0.055433
# compression-ratio  0.186105  ...   -0.205717 -0.435936  0.324701    -0.223411
# horsepower         0.088133  ...    1.000000  0.130971 -0.803140     0.801418
# peak-rpm          -0.066844  ...    0.130971  1.000000 -0.113723     0.016127
# city-mpg          -0.042179  ...   -0.803140 -0.113723  1.000000    -0.908439
# highway-mpg        0.055433  ...    0.801418  0.016127 -0.908439     1.000000
# price              0.082095  ...    0.757946 -0.100854 -0.667449     0.789346
# city-L/100km       0.042550  ...    0.871708  0.120653 -0.950493     0.955195
# diesel             0.241820  ...   -0.165169 -0.477060  0.255963    -0.153710
# gas               -0.241820  ...    0.165169  0.477060 -0.255963     0.153710
# aspiration-std    -0.222970  ...   -0.240212  0.183629  0.202362    -0.225795
# aspiration-turbo   0.222970  ...    0.240212 -0.183629 -0.202362     0.225795
#
#                       price  city-L/100km    diesel       gas  aspiration-std  \
# symboling         -0.082201      0.063165 -0.194311  0.194311        0.059866
# normalized-losses  0.133999      0.232682 -0.101437  0.101437        0.006823
# wheel-base         0.583168      0.474040  0.308346 -0.308346       -0.257611
# length             0.682986      0.659165  0.212679 -0.212679       -0.234539
# width              0.728699      0.682850  0.233880 -0.233880       -0.300567
# height             0.134388     -0.002333  0.284631 -0.284631       -0.087311
# curb-weight        0.820825      0.791911  0.217275 -0.217275       -0.324902
# engine-size        0.861752      0.744952  0.069594 -0.069594       -0.108217
# bore               0.532300      0.555960  0.054457 -0.054457       -0.212623
# stroke             0.082095      0.042550  0.241820 -0.241820       -0.222970
# compression-ratio  0.070990     -0.296964  0.984356 -0.984356       -0.295541
# horsepower         0.757946      0.871708 -0.165169  0.165169       -0.240212
# peak-rpm          -0.100854      0.120653 -0.477060  0.477060        0.183629
# city-mpg          -0.667449     -0.950493  0.255963 -0.255963        0.202362
# highway-mpg        0.789346      0.955195 -0.153710  0.153710       -0.225795
# price              1.000000      0.770411  0.110207 -0.110207       -0.177285
# city-L/100km       0.770411      1.000000 -0.235766  0.235766       -0.174182
# diesel             0.110207     -0.235766  1.000000 -1.000000       -0.401397
# gas               -0.110207      0.235766 -1.000000  1.000000        0.401397
# aspiration-std    -0.177285     -0.174182 -0.401397  0.401397        1.000000
# aspiration-turbo   0.177285      0.174182  0.401397 -0.401397       -1.000000
#
#                    aspiration-turbo
# symboling                 -0.059866
# normalized-losses         -0.006823
# wheel-base                 0.257611
# length                     0.234539
# width                      0.300567
# height                     0.087311
# curb-weight                0.324902
# engine-size                0.108217
# bore                       0.212623
# stroke                     0.222970
# compression-ratio          0.295541
# horsepower                 0.240212
# peak-rpm                  -0.183629
# city-mpg                  -0.202362
# highway-mpg                0.225795
# price                      0.177285
# city-L/100km               0.174182
# diesel                     0.401397
# gas                       -0.401397
# aspiration-std            -1.000000
# aspiration-turbo           1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# # Find the correlation between the following columns: bore, stroke,compression-ratio , and horsepower

# %%
df[["bore","stroke","compression-ratio","horsepower"]].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055909           0.005201    0.575707
# stroke            -0.055909  1.000000           0.186105    0.088133
# compression-ratio  0.005201  0.186105           1.000000   -0.205717
# horsepower         0.575707  0.088133          -0.205717    1.000000

# %% [markdown]
# ## Continuous numerical variables:
#
# Continuous numerical variables are variables that may contain any value within some range. Continuous numerical variables can have the type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.
#
# In order to start understanding the (linear) relationship between an individual variable and the price. We can do this by using "regplot", which plots the scatterplot plus the fitted regression line for the data.
#
# Let's find the scatterplot of "engine-size" and "price"

# %%
df[["engine-size","price"]].head()
# Out:
#    engine-size    price
# 0          130  13495.0
# 1          130  16500.0
# 2          152  16500.0
# 3          109  13950.0
# 4          136  17450.0

# %%
# Engine size as potential predictor variable for price
sns.regplot(x="engine-size",y="price",data=df,color='r')
plt.ylim(0,)
# Out:
# (0.0, 52284.65972696126)

# %%
df[["engine-size","price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.861752
# price           0.861752  1.000000

# %%
df[["highway-mpg","price"]].head()
# Out:
#    highway-mpg    price
# 0     8.703704  13495.0
# 1     8.703704  16500.0
# 2     9.038462  16500.0
# 3     7.833333  13950.0
# 4    10.681818  17450.0

# %%
sns.regplot(x="highway-mpg",y="price",data=df,color='r')
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# ## Weak Linear Relationship

# %%
sns.regplot(x="peak-rpm",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %%
df[["peak-rpm","price"]].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.100854
# price    -0.100854  1.000000

# %%
sns.regplot(x="price",y="stroke",data=df)
df[["stroke","price"]].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.082095
# price   0.082095  1.000000

# %% [markdown]
# ## Categorical variables
# These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.
#
# Let's look at the relationship between "body-style" and "price"

# %%
sns.boxplot(x="body-style",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x="engine-location",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='engine-location', ylabel='price'>

# %%
sns.boxplot(x="drive-wheels",y="price",data=df)
# Out:
# <AxesSubplot:xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# <h2 id="discriptive_statistics">3. Descriptive Statistical Analysis</h2>
# <p>Let's first take a look at the variables by utilizing a description method.</p>
#
# <p>The <b>describe</b> function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped in these statistics.</p>
#
# This will show:
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         205.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585    0.836373    0.911588
# std      1.245307          31.681008    6.021776    0.059285    0.029671
# min     -2.000000          65.000000   86.600000    0.678039    0.834025
# 25%      0.000000         101.000000   94.500000    0.799135    0.886584
# 50%      1.000000         122.000000   97.000000    0.832292    0.905947
# 75%      2.000000         137.000000  102.400000    0.879865    0.925311
# max      3.000000         256.000000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  ...  \
# count  205.000000   205.000000   205.000000  205.000000  205.000000  ...
# mean     0.898409  2555.565854   126.907317    3.329751    3.255423  ...
# std      0.040862   520.680204    41.642693    0.270844    0.313597  ...
# min      0.799331  1488.000000    61.000000    2.540000    2.070000  ...
# 25%      0.869565  2145.000000    97.000000    3.150000    3.110000  ...
# 50%      0.904682  2414.000000   120.000000    3.310000    3.290000  ...
# 75%      0.928094  2935.000000   141.000000    3.580000    3.410000  ...
# max      1.000000  4066.000000   326.000000    3.940000    4.170000  ...
#
#        horsepower     peak-rpm    city-mpg  highway-mpg         price  \
# count  205.000000   205.000000  205.000000   205.000000    205.000000
# mean   104.253659  5125.369458   25.219512     8.034347  13207.129353
# std     39.519219   476.979093    6.542142     1.849782   7868.768212
# min     48.000000  4150.000000   13.000000     4.351852   5118.000000
# 25%     70.000000  4800.000000   19.000000     6.911765   7788.000000
# 50%     95.000000  5200.000000   24.000000     7.833333  10595.000000
# 75%    116.000000  5500.000000   30.000000     9.400000  16500.000000
# max    288.000000  6600.000000   49.000000    14.687500  45400.000000
#
#        city-L/100km      diesel         gas  aspiration-std  aspiration-turbo
# count    205.000000  205.000000  205.000000      205.000000        205.000000
# mean       9.949525    0.097561    0.902439        0.819512          0.180488
# std        2.573104    0.297446    0.297446        0.385535          0.385535
# min        4.795918    0.000000    0.000000        0.000000          0.000000
# 25%        7.833333    0.000000    1.000000        1.000000          0.000000
# 50%        9.791667    0.000000    1.000000        1.000000          0.000000
# 75%       12.368421    0.000000    1.000000        1.000000          0.000000
# max       18.076923    1.000000    1.000000        1.000000          1.000000
#
# [8 rows x 21 columns]

# %%
df.describe(include=['object'])
# Out:
#           make num-of-doors body-style drive-wheels engine-location  \
# count      205          205        205          205             205
# unique      22            2          5            3               2
# top     toyota         four      sedan          fwd           front
# freq        32          116         96          120             202
#
#        engine-type num-of-cylinders fuel-system Horsepowerbinned
# count          205              205         205              205
# unique           7                7           8                3
# top            ohc             four        mpfi              low
# freq           148              159          94              163

# %%
from scipy import stats

# %% [markdown]
# ### Wheel-base Vs Price

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'],df['price'])
print("The Pearson Coeffient is", pearson_coef,"and the p_value is",p_value)
# Out:
# The Pearson Coeffient is 0.5831681499789549 and the p_value is 4.527625545686636e-20

# %%
pearson_coef, P_value= stats.pearsonr(df['horsepower'],df['price'])
print("The Pearson Coefficient is",pearson_coef,"and the p_value is",p_value)
# Out:
# The Pearson Coefficient is 0.7579459704465278 and the p_value is 4.527625545686636e-20

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6829862954386218  with a P-value of P =  1.649887329121877e-29

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.7286988175931834  with a P-value of P = 3.2145204838050753e-35

# %%
pearson_coef , p_value= stats.pearsonr(df['curb-weight'],df['price'],)
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8208247333547288  with a P-value of P =  2.8663321070274196e-51

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.861752243685972  with a P-value of P = 9.669661923635875e-62

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("The Pearsoan Correlation Coefficient is", pearson_coef, " with a P-value of P =  ", p_value )
# Out:
# The Pearsoan Correlation Coefficient is 0.5323000195387406  with a P-value of P =   2.1398306512856245e-16

# %%
pearson_coef, p_value = stats.pearsonr(df['city-mpg'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6674492651600004  with a P-value of P =  8.463700497727807e-28

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.7893464215248446  with a P-value of P =  6.91574669541859e-45
