# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# %%
df = pd.read_csv('datasets/hotel.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
X = df.copy()
y = X.pop('is_canceled')

# %%
X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

# %%
features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]

# %%
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

# %%
transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)

# %%
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

# %%
preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# %%
X_train,X_valid, y_train, y_valid = train_test_split(X, y , stratify=y, train_size=0.75)

# %%
X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

# %%
input_shape = [X_train.shape[1]]

# %% [markdown]
# ## Model Preparation

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([layers.BatchNormalization(input_shape=input_shape),
                             layers.Dense(256,activation='relu'),
                             layers.BatchNormalization(),
                             layers.Dropout(0.3),
                             layers.Dense(256,activation='relu'),
                             layers.BatchNormalization(),
                             layers.Dropout(0.3),
                             layers.Dense(1,activation='sigmoid')])

# %%
model.compile(optimizer=keras.optimizers.Adam(lr=0.001),loss='binary_crossentropy',metrics=['binary_accuracy'])

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4796 - binary_accuracy: 0.7746 - val_loss: 0.4290 - val_binary_accuracy: 0.7942
# Epoch 2/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4221 - binary_accuracy: 0.8018 - val_loss: 0.4016 - val_binary_accuracy: 0.8111
# Epoch 3/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4099 - binary_accuracy: 0.8087 - val_loss: 0.3916 - val_binary_accuracy: 0.8150
# Epoch 4/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4023 - binary_accuracy: 0.8115 - val_loss: 0.3866 - val_binary_accuracy: 0.8187
# Epoch 5/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3967 - binary_accuracy: 0.8158 - val_loss: 0.3845 - val_binary_accuracy: 0.8216
# Epoch 6/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3929 - binary_accuracy: 0.8172 - val_loss: 0.3799 - val_binary_accuracy: 0.8229
# Epoch 7/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3904 - binary_accuracy: 0.8179 - val_loss: 0.3784 - val_binary_accuracy: 0.8232
# Epoch 8/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3852 - binary_accuracy: 0.8207 - val_loss: 0.3750 - val_binary_accuracy: 0.8263
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3823 - binary_accuracy: 0.8221 - val_loss: 0.3746 - val_binary_accuracy: 0.8283
# Epoch 10/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3799 - binary_accuracy: 0.8241 - val_loss: 0.3697 - val_binary_accuracy: 0.8265
# Epoch 11/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3774 - binary_accuracy: 0.8258 - val_loss: 0.3683 - val_binary_accuracy: 0.8312
# Epoch 12/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3754 - binary_accuracy: 0.8270 - val_loss: 0.3678 - val_binary_accuracy: 0.8314
# Epoch 13/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3721 - binary_accuracy: 0.8277 - val_loss: 0.3701 - val_binary_accuracy: 0.8306
# Epoch 14/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3712 - binary_accuracy: 0.8279 - val_loss: 0.3638 - val_binary_accuracy: 0.8350
# Epoch 15/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3695 - binary_accuracy: 0.8297 - val_loss: 0.3627 - val_binary_accuracy: 0.8333
# Epoch 16/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3658 - binary_accuracy: 0.8312 - val_loss: 0.3628 - val_binary_accuracy: 0.8328
# Epoch 17/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3661 - binary_accuracy: 0.8304 - val_loss: 0.3590 - val_binary_accuracy: 0.8348
# Epoch 18/200
# 175/175 [==============================] - 1s 8ms/step - loss: 0.3639 - binary_accuracy: 0.8313 - val_loss: 0.3581 - val_binary_accuracy: 0.8343
# Epoch 19/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3617 - binary_accuracy: 0.8319 - val_loss: 0.3588 - val_binary_accuracy: 0.8364
# Epoch 20/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3608 - binary_accuracy: 0.8332 - val_loss: 0.3585 - val_binary_accuracy: 0.8347
# Epoch 21/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3598 - binary_accuracy: 0.8340 - val_loss: 0.3553 - val_binary_accuracy: 0.8372
# Epoch 22/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3577 - binary_accuracy: 0.8347 - val_loss: 0.3569 - val_binary_accuracy: 0.8346
# Epoch 23/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3562 - binary_accuracy: 0.8336 - val_loss: 0.3556 - val_binary_accuracy: 0.8363
# Epoch 24/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3540 - binary_accuracy: 0.8372 - val_loss: 0.3540 - val_binary_accuracy: 0.8383
# Epoch 25/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3545 - binary_accuracy: 0.8360 - val_loss: 0.3547 - val_binary_accuracy: 0.8383
# Epoch 26/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3529 - binary_accuracy: 0.8376 - val_loss: 0.3535 - val_binary_accuracy: 0.8377
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3529 - binary_accuracy: 0.8372 - val_loss: 0.3537 - val_binary_accuracy: 0.8378
# Epoch 28/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3508 - binary_accuracy: 0.8376 - val_loss: 0.3515 - val_binary_accuracy: 0.8384
# Epoch 29/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3491 - binary_accuracy: 0.8390 - val_loss: 0.3514 - val_binary_accuracy: 0.8379
# Epoch 30/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3505 - binary_accuracy: 0.8380 - val_loss: 0.3496 - val_binary_accuracy: 0.8385
# Epoch 31/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3478 - binary_accuracy: 0.8387 - val_loss: 0.3498 - val_binary_accuracy: 0.8399
# Epoch 32/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3476 - binary_accuracy: 0.8391 - val_loss: 0.3499 - val_binary_accuracy: 0.8391
# Epoch 33/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3452 - binary_accuracy: 0.8400 - val_loss: 0.3491 - val_binary_accuracy: 0.8406
# Epoch 34/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3441 - binary_accuracy: 0.8408 - val_loss: 0.3485 - val_binary_accuracy: 0.8396
# Epoch 35/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3442 - binary_accuracy: 0.8404 - val_loss: 0.3485 - val_binary_accuracy: 0.8404
# Epoch 36/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3442 - binary_accuracy: 0.8404 - val_loss: 0.3478 - val_binary_accuracy: 0.8400
# Epoch 37/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3431 - binary_accuracy: 0.8405 - val_loss: 0.3476 - val_binary_accuracy: 0.8402
# Epoch 38/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3423 - binary_accuracy: 0.8412 - val_loss: 0.3469 - val_binary_accuracy: 0.8400
# Epoch 39/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3405 - binary_accuracy: 0.8426 - val_loss: 0.3478 - val_binary_accuracy: 0.8383
# Epoch 40/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3405 - binary_accuracy: 0.8424 - val_loss: 0.3464 - val_binary_accuracy: 0.8410
# Epoch 41/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3396 - binary_accuracy: 0.8432 - val_loss: 0.3458 - val_binary_accuracy: 0.8430
# Epoch 42/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3379 - binary_accuracy: 0.8434 - val_loss: 0.3469 - val_binary_accuracy: 0.8420
# Epoch 43/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3391 - binary_accuracy: 0.8429 - val_loss: 0.3468 - val_binary_accuracy: 0.8411
# Epoch 44/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3363 - binary_accuracy: 0.8438 - val_loss: 0.3475 - val_binary_accuracy: 0.8407
# Epoch 45/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3373 - binary_accuracy: 0.8430 - val_loss: 0.3458 - val_binary_accuracy: 0.8423
# Epoch 46/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3371 - binary_accuracy: 0.8441 - val_loss: 0.3463 - val_binary_accuracy: 0.8415
# <AxesSubplot:title={'center':'Accuracy'}>
